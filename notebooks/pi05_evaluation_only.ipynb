# %% [markdown]
# * git pull
# * env installation
# * run unified_model_inference script

# %%
import os

from dotenv import find_dotenv, load_dotenv

# %load_ext dotenv
# %dotenv -o
load_dotenv(find_dotenv(), override=True)
# Out:
# The dotenv extension is already loaded. To reload it, use:
#   %reload_ext dotenv
# True

# %%
HF_TOKEN = os.environ.get("HF_TOKEN")

# %%
# !hf auth login --token $HF_TOKEN --add-to-git-credential
# Out:
# Token is valid (permission: fineGrained).
# The token `work-oracle-node` has been saved to /home/ashah/.cache/huggingface/stored_tokens
# Your token has been saved in your configured git credential helpers (store).
# Your token has been saved to /home/ashah/.cache/huggingface/token
# Login successful.
# Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.

# %%
! accelerate launch ../src/opentau/scripts/unified_model_inference.py --config_path=../configs/examples/pi05_config.json
# Out:
# /home/ashah/Documents/OpenTau/src/opentau/datasets/lerobot_dataset.py:1102: UserWarning: Using local=True with _sync=True when decorating LeRobotDataset.push_to_hub forces a wait_for_everyone. But the broadcast is not necessary returning the correct result on all nodes.
#   def push_to_hub(
# /home/ashah/Documents/OpenTau/src/opentau/datasets/lerobot_dataset.py:1159: UserWarning: Using local=True with _sync=True when decorating LeRobotDataset.pull_from_repo forces a wait_for_everyone. But the broadcast is not necessary returning the correct result on all nodes.
#   def pull_from_repo(
# INFO 2026-01-06 10:50:15 ion_pi05.py:179 Setting init_strategy to 'no_init' because we are resuming from a checkpoint.
# INFO 2026-01-06 10:50:15 inference.py:37 {'action_chunk': 50,
#  'batch_size': 2,
#  'dataloader_batch_size': 2,
#  'dataset_mixture': {'action_freq': 30.0,
#                      'datasets': [{'data_features_name_mapping': None,
#                                    'episodes': None,
#                                    'grounding': None,
#                                    'image_transforms': {'enable': False,
#                                                         'max_num_transforms': 3,
#                                                         'random_order': False,
#                                                         'tfs': {'brightness': {'kwargs': {'brightness': (0.8,
#                                                                                                          1.2)},
#                                                                                'type': 'ColorJitter',
#                                                                                'weight': 1.0},
#                                                                 'contrast': {'kwargs': {'contrast': (0.8,
#                                                                                                      1.2)},
#                                                                              'type': 'ColorJitter',
#                                                                              'weight': 1.0},
#                                                                 'hue': {'kwargs': {'hue': (-0.05,
#                                                                                            0.05)},
#                                                                         'type': 'ColorJitter',
#                                                                         'weight': 1.0},
#                                                                 'saturation': {'kwargs': {'saturation': (0.5,
#                                                                                                          1.5)},
#                                                                                'type': 'ColorJitter',
#                                                                                'weight': 1.0},
#                                                                 'sharpness': {'kwargs': {'sharpness': (0.5,
#                                                                                                        1.5)},
#                                                                               'type': 'SharpnessJitter',
#                                                                               'weight': 1.0}}},
#                                    'loss_type_mapping': None,
#                                    'repo_id': 'lerobot/droid_100',
#                                    'revision': None,
#                                    'root': None,
#                                    'stats': None,
#                                    'use_imagenet_stats': True,
#                                    'video_backend': 'torchcodec'}],
#                      'image_resample_strategy': 'nearest',
#                      'vector_resample_strategy': 'nearest',
#                      'weights': [1.0]},
#  'debug': False,
#  'env': None,
#  'eval': {'batch_size': 16,
#           'grid_size': None,
#           'max_episodes_rendered': 16,
#           'n_episodes': 16,
#           'recording_root': None,
#           'use_async_envs': True},
#  'eval_freq': 0,
#  'gradient_accumulation_steps': 1,
#  'job_name': None,
#  'last_checkpoint_only': True,
#  'log_freq': 1,
#  'loss_weighting': {'CE': 1.0, 'MSE': 10.0},
#  'max_action_dim': 32,
#  'max_state_dim': 32,
#  'num_cams': 2,
#  'num_workers': 4,
#  'optimizer': {'betas': (0.9, 0.95),
#                'eps': 1e-08,
#                'grad_clip_norm': 10.0,
#                'lr': 2.5e-05,
#                'weight_decay': 1e-10},
#  'output_dir': None,
#  'policy': {'action_decoder_latency_lower': 0.0,
#             'action_decoder_latency_mean': 0.0,
#             'action_decoder_latency_std': 0.0,
#             'action_decoder_latency_upper': 0.0,
#             'adapt_to_pi_aloha': False,
#             'attention_implementation': 'eager',
#             'chunk_size': 50,
#             'cloud_vlm_latency_lower': 0.0,
#             'cloud_vlm_latency_mean': 0.0,
#             'cloud_vlm_latency_std': 0.0,
#             'cloud_vlm_latency_upper': 0.0,
#             'device': None,
#             'discrete_action_max_length': 60,
#             'dropout': 0.1,
#             'empty_cameras': 0,
#             'freeze_vision_encoder': True,
#             'init_strategy': 'no_init',
#             'input_features': {'camera0': {'shape': (3, 224, 224),
#                                            'type': <FeatureType.VISUAL: 'VISUAL'>},
#                                'camera1': {'shape': (3, 224, 224),
#                                            'type': <FeatureType.VISUAL: 'VISUAL'>},
#                                'state': {'shape': (32,),
#                                          'type': <FeatureType.STATE: 'STATE'>}},
#             'max_action_dim': 32,
#             'max_state_dim': 32,
#             'n_action_steps': 10,
#             'n_obs_steps': 1,
#             'normalization_mapping': {'ACTION': <NormalizationMode.MEAN_STD: 'MEAN_STD'>,
#                                       'STATE': <NormalizationMode.MIN_MAX: 'MIN_MAX'>,
#                                       'VISUAL': <NormalizationMode.IDENTITY: 'IDENTITY'>},
#             'num_steps': 10,
#             'optimizer_betas': (0.9, 0.95),
#             'optimizer_eps': 1e-08,
#             'optimizer_lr': 2.5e-05,
#             'optimizer_weight_decay': 1e-10,
#             'output_features': {'actions': {'shape': (32,),
#                                             'type': <FeatureType.ACTION: 'ACTION'>}},
#             'pretrained_path': 'TensorAuto/tPi0.5-libero',
#             'proj_width': 1024,
#             'resize_imgs_with_padding': (224, 224),
#             'scheduler_decay_lr': 2.5e-06,
#             'scheduler_decay_steps': 30000,
#             'scheduler_warmup_steps': 1000,
#             'tokenizer_max_length': 256,
#             'train_expert_only': True,
#             'use_amp': False,
#             'use_cache': True,
#             'use_delta_joint_actions_aloha': False},
#  'prefetch_factor': 8,
#  'resolution': (224, 224),
#  'resume': False,
#  'save_checkpoint': True,
#  'save_freq': 100,
#  'scheduler': {'decay_lr': 2.5e-06,
#                'num_decay_steps': 30000,
#                'num_warmup_steps': 1000,
#                'peak_lr': 2.5e-05},
#  'seed': 1000,
#  'steps': 100,
#  'trace_nans': True,
#  'use_policy_training_preset': True,
#  'wandb': {'allow_resume': True,
#            'disable_artifact': False,
#            'enable': True,
#            'entity': 'wyautox-autox',
#            'group': None,
#            'job_type': None,
#            'mode': None,
#            'name': None,
#            'notes': 'Dev config for pi0.5',
#            'project': 'pi05',
#            'run_id': None,
#            'tags': []}}
# INFO 2026-01-06 10:50:15 inference.py:45 Creating policy
# Loading model from: TensorAuto/tPi0.5-libero
# ✓ Loaded state dict from model.safetensors
# WARNING 2026-01-06 10:51:10 ing_pi05.py:489 Vision embedding key might need handling: model.paligemma_with_expert.paligemma.model.vision_tower.vision_model.embeddings.patch_embedding.bias
# WARNING 2026-01-06 10:51:10 ing_pi05.py:489 Vision embedding key might need handling: model.paligemma_with_expert.paligemma.model.vision_tower.vision_model.embeddings.patch_embedding.weight
# All keys loaded successfully!
# INFO 2026-01-06 10:51:45 ls/utils.py:353 Attempting to compile the policy with torch.compile()...
# INFO 2026-01-06 10:51:46 ls/utils.py:357 Policy compiled successfully.
# dict_keys(['camera0', 'camera1', 'state', 'prompt', 'img_is_pad', 'action_is_pad'])
# WARNING 2026-01-06 10:51:46 ing_pi05.py:660 State values are not normalized between -1 and 1. Min: -1.2109375, Max: 0.9296875
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# WARNING 2026-01-06 10:51:47 ing_pi05.py:660 State values are not normalized between -1 and 1. Min: -1.2109375, Max: 0.9296875
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# WARNING 2026-01-06 10:51:47 ing_pi05.py:660 State values are not normalized between -1 and 1. Min: -1.2109375, Max: 0.9296875
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# WARNING 2026-01-06 10:51:47 ing_pi05.py:660 State values are not normalized between -1 and 1. Min: -1.2109375, Max: 0.9296875
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# WARNING 2026-01-06 10:51:48 ing_pi05.py:660 State values are not normalized between -1 and 1. Min: -1.2109375, Max: 0.9296875
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# WARNING 2026-01-06 10:51:48 ing_pi05.py:660 State values are not normalized between -1 and 1. Min: -1.2109375, Max: 0.9296875
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# WARNING 2026-01-06 10:51:49 ing_pi05.py:660 State values are not normalized between -1 and 1. Min: -1.2109375, Max: 0.9296875
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# WARNING 2026-01-06 10:51:49 ing_pi05.py:660 State values are not normalized between -1 and 1. Min: -1.2109375, Max: 0.9296875
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# WARNING 2026-01-06 10:51:50 ing_pi05.py:660 State values are not normalized between -1 and 1. Min: -1.2109375, Max: 0.9296875
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# WARNING 2026-01-06 10:51:50 ing_pi05.py:660 State values are not normalized between -1 and 1. Min: -1.2109375, Max: 0.9296875
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# WARNING 2026-01-06 10:51:50 ing_pi05.py:660 State values are not normalized between -1 and 1. Min: -1.2109375, Max: 0.9296875
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# WARNING 2026-01-06 10:51:51 ing_pi05.py:660 State values are not normalized between -1 and 1. Min: -1.2109375, Max: 0.9296875
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# WARNING 2026-01-06 10:51:51 ing_pi05.py:660 State values are not normalized between -1 and 1. Min: -1.2109375, Max: 0.9296875
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# WARNING 2026-01-06 10:51:52 ing_pi05.py:660 State values are not normalized between -1 and 1. Min: -1.2109375, Max: 0.9296875
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# WARNING 2026-01-06 10:51:52 ing_pi05.py:660 State values are not normalized between -1 and 1. Min: -1.2109375, Max: 0.9296875
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# WARNING 2026-01-06 10:51:52 ing_pi05.py:660 State values are not normalized between -1 and 1. Min: -1.2109375, Max: 0.9296875
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# WARNING 2026-01-06 10:51:53 ing_pi05.py:660 State values are not normalized between -1 and 1. Min: -1.2109375, Max: 0.9296875
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# WARNING 2026-01-06 10:51:53 ing_pi05.py:660 State values are not normalized between -1 and 1. Min: -1.2109375, Max: 0.9296875
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# WARNING 2026-01-06 10:51:54 ing_pi05.py:660 State values are not normalized between -1 and 1. Min: -1.2109375, Max: 0.9296875
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# WARNING 2026-01-06 10:51:54 ing_pi05.py:660 State values are not normalized between -1 and 1. Min: -1.2109375, Max: 0.9296875
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# WARNING 2026-01-06 10:51:54 ing_pi05.py:660 State values are not normalized between -1 and 1. Min: -1.2109375, Max: 0.9296875
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# WARNING 2026-01-06 10:51:55 ing_pi05.py:660 State values are not normalized between -1 and 1. Min: -1.2109375, Max: 0.9296875
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# WARNING 2026-01-06 10:51:55 ing_pi05.py:660 State values are not normalized between -1 and 1. Min: -1.2109375, Max: 0.9296875
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# WARNING 2026-01-06 10:51:56 ing_pi05.py:660 State values are not normalized between -1 and 1. Min: -1.2109375, Max: 0.9296875
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# WARNING 2026-01-06 10:51:56 ing_pi05.py:660 State values are not normalized between -1 and 1. Min: -1.2109375, Max: 0.9296875
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# WARNING 2026-01-06 10:51:57 ing_pi05.py:660 State values are not normalized between -1 and 1. Min: -1.2109375, Max: 0.9296875
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# WARNING 2026-01-06 10:51:57 ing_pi05.py:660 State values are not normalized between -1 and 1. Min: -1.2109375, Max: 0.9296875
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# WARNING 2026-01-06 10:51:57 ing_pi05.py:660 State values are not normalized between -1 and 1. Min: -1.2109375, Max: 0.9296875
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# WARNING 2026-01-06 10:51:58 ing_pi05.py:660 State values are not normalized between -1 and 1. Min: -1.2109375, Max: 0.9296875
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# WARNING 2026-01-06 10:51:58 ing_pi05.py:660 State values are not normalized between -1 and 1. Min: -1.2109375, Max: 0.9296875
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# WARNING 2026-01-06 10:51:59 ing_pi05.py:660 State values are not normalized between -1 and 1. Min: -1.2109375, Max: 0.9296875
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# WARNING 2026-01-06 10:51:59 ing_pi05.py:660 State values are not normalized between -1 and 1. Min: -1.2109375, Max: 0.9296875
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# WARNING 2026-01-06 10:51:59 ing_pi05.py:660 State values are not normalized between -1 and 1. Min: -1.2109375, Max: 0.9296875
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# WARNING 2026-01-06 10:52:00 ing_pi05.py:660 State values are not normalized between -1 and 1. Min: -1.2109375, Max: 0.9296875
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# WARNING 2026-01-06 10:52:00 ing_pi05.py:660 State values are not normalized between -1 and 1. Min: -1.2109375, Max: 0.9296875
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# WARNING 2026-01-06 10:52:01 ing_pi05.py:660 State values are not normalized between -1 and 1. Min: -1.2109375, Max: 0.9296875
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# WARNING 2026-01-06 10:52:01 ing_pi05.py:660 State values are not normalized between -1 and 1. Min: -1.2109375, Max: 0.9296875
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# WARNING 2026-01-06 10:52:02 ing_pi05.py:660 State values are not normalized between -1 and 1. Min: -1.2109375, Max: 0.9296875
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# WARNING 2026-01-06 10:52:02 ing_pi05.py:660 State values are not normalized between -1 and 1. Min: -1.2109375, Max: 0.9296875
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# WARNING 2026-01-06 10:52:02 ing_pi05.py:660 State values are not normalized between -1 and 1. Min: -1.2109375, Max: 0.9296875
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# WARNING 2026-01-06 10:52:03 ing_pi05.py:660 State values are not normalized between -1 and 1. Min: -1.2109375, Max: 0.9296875
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# WARNING 2026-01-06 10:52:03 ing_pi05.py:660 State values are not normalized between -1 and 1. Min: -1.2109375, Max: 0.9296875
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# WARNING 2026-01-06 10:52:04 ing_pi05.py:660 State values are not normalized between -1 and 1. Min: -1.2109375, Max: 0.9296875
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# WARNING 2026-01-06 10:52:04 ing_pi05.py:660 State values are not normalized between -1 and 1. Min: -1.2109375, Max: 0.9296875
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# WARNING 2026-01-06 10:52:04 ing_pi05.py:660 State values are not normalized between -1 and 1. Min: -1.2109375, Max: 0.9296875
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# WARNING 2026-01-06 10:52:05 ing_pi05.py:660 State values are not normalized between -1 and 1. Min: -1.2109375, Max: 0.9296875
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# WARNING 2026-01-06 10:52:05 ing_pi05.py:660 State values are not normalized between -1 and 1. Min: -1.2109375, Max: 0.9296875
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# WARNING 2026-01-06 10:52:06 ing_pi05.py:660 State values are not normalized between -1 and 1. Min: -1.2109375, Max: 0.9296875
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# WARNING 2026-01-06 10:52:06 ing_pi05.py:660 State values are not normalized between -1 and 1. Min: -1.2109375, Max: 0.9296875
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# WARNING 2026-01-06 10:52:07 ing_pi05.py:660 State values are not normalized between -1 and 1. Min: -1.2109375, Max: 0.9296875
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# WARNING 2026-01-06 10:52:07 ing_pi05.py:660 State values are not normalized between -1 and 1. Min: -1.2109375, Max: 0.9296875
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# WARNING 2026-01-06 10:52:07 ing_pi05.py:660 State values are not normalized between -1 and 1. Min: -1.2109375, Max: 0.9296875
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# WARNING 2026-01-06 10:52:08 ing_pi05.py:660 State values are not normalized between -1 and 1. Min: -1.2109375, Max: 0.9296875
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# WARNING 2026-01-06 10:52:08 ing_pi05.py:660 State values are not normalized between -1 and 1. Min: -1.2109375, Max: 0.9296875
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# WARNING 2026-01-06 10:52:09 ing_pi05.py:660 State values are not normalized between -1 and 1. Min: -1.2109375, Max: 0.9296875
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# WARNING 2026-01-06 10:52:09 ing_pi05.py:660 State values are not normalized between -1 and 1. Min: -1.2109375, Max: 0.9296875
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# WARNING 2026-01-06 10:52:10 ing_pi05.py:660 State values are not normalized between -1 and 1. Min: -1.2109375, Max: 0.9296875
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# WARNING 2026-01-06 10:52:10 ing_pi05.py:660 State values are not normalized between -1 and 1. Min: -1.2109375, Max: 0.9296875
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# WARNING 2026-01-06 10:52:10 ing_pi05.py:660 State values are not normalized between -1 and 1. Min: -1.2109375, Max: 0.9296875
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# WARNING 2026-01-06 10:52:11 ing_pi05.py:660 State values are not normalized between -1 and 1. Min: -1.2109375, Max: 0.9296875
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# WARNING 2026-01-06 10:52:11 ing_pi05.py:660 State values are not normalized between -1 and 1. Min: -1.2109375, Max: 0.9296875
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# WARNING 2026-01-06 10:52:12 ing_pi05.py:660 State values are not normalized between -1 and 1. Min: -1.2109375, Max: 0.9296875
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# WARNING 2026-01-06 10:52:12 ing_pi05.py:660 State values are not normalized between -1 and 1. Min: -1.2109375, Max: 0.9296875
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# WARNING 2026-01-06 10:52:12 ing_pi05.py:660 State values are not normalized between -1 and 1. Min: -1.2109375, Max: 0.9296875
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# WARNING 2026-01-06 10:52:13 ing_pi05.py:660 State values are not normalized between -1 and 1. Min: -1.2109375, Max: 0.9296875
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# WARNING 2026-01-06 10:52:13 ing_pi05.py:660 State values are not normalized between -1 and 1. Min: -1.2109375, Max: 0.9296875
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# WARNING 2026-01-06 10:52:14 ing_pi05.py:660 State values are not normalized between -1 and 1. Min: -1.2109375, Max: 0.9296875
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# WARNING 2026-01-06 10:52:14 ing_pi05.py:660 State values are not normalized between -1 and 1. Min: -1.2109375, Max: 0.9296875
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# WARNING 2026-01-06 10:52:15 ing_pi05.py:660 State values are not normalized between -1 and 1. Min: -1.2109375, Max: 0.9296875
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# WARNING 2026-01-06 10:52:15 ing_pi05.py:660 State values are not normalized between -1 and 1. Min: -1.2109375, Max: 0.9296875
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# WARNING 2026-01-06 10:52:15 ing_pi05.py:660 State values are not normalized between -1 and 1. Min: -1.2109375, Max: 0.9296875
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# WARNING 2026-01-06 10:52:16 ing_pi05.py:660 State values are not normalized between -1 and 1. Min: -1.2109375, Max: 0.9296875
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# WARNING 2026-01-06 10:52:16 ing_pi05.py:660 State values are not normalized between -1 and 1. Min: -1.2109375, Max: 0.9296875
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# WARNING 2026-01-06 10:52:17 ing_pi05.py:660 State values are not normalized between -1 and 1. Min: -1.2109375, Max: 0.9296875
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# WARNING 2026-01-06 10:52:17 ing_pi05.py:660 State values are not normalized between -1 and 1. Min: -1.2109375, Max: 0.9296875
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# WARNING 2026-01-06 10:52:17 ing_pi05.py:660 State values are not normalized between -1 and 1. Min: -1.2109375, Max: 0.9296875
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# WARNING 2026-01-06 10:52:18 ing_pi05.py:660 State values are not normalized between -1 and 1. Min: -1.2109375, Max: 0.9296875
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# WARNING 2026-01-06 10:52:18 ing_pi05.py:660 State values are not normalized between -1 and 1. Min: -1.2109375, Max: 0.9296875
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# WARNING 2026-01-06 10:52:19 ing_pi05.py:660 State values are not normalized between -1 and 1. Min: -1.2109375, Max: 0.9296875
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# WARNING 2026-01-06 10:52:19 ing_pi05.py:660 State values are not normalized between -1 and 1. Min: -1.2109375, Max: 0.9296875
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# WARNING 2026-01-06 10:52:19 ing_pi05.py:660 State values are not normalized between -1 and 1. Min: -1.2109375, Max: 0.9296875
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# WARNING 2026-01-06 10:52:20 ing_pi05.py:660 State values are not normalized between -1 and 1. Min: -1.2109375, Max: 0.9296875
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# WARNING 2026-01-06 10:52:20 ing_pi05.py:660 State values are not normalized between -1 and 1. Min: -1.2109375, Max: 0.9296875
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# WARNING 2026-01-06 10:52:21 ing_pi05.py:660 State values are not normalized between -1 and 1. Min: -1.2109375, Max: 0.9296875
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# WARNING 2026-01-06 10:52:21 ing_pi05.py:660 State values are not normalized between -1 and 1. Min: -1.2109375, Max: 0.9296875
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# WARNING 2026-01-06 10:52:22 ing_pi05.py:660 State values are not normalized between -1 and 1. Min: -1.2109375, Max: 0.9296875
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# WARNING 2026-01-06 10:52:22 ing_pi05.py:660 State values are not normalized between -1 and 1. Min: -1.2109375, Max: 0.9296875
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# WARNING 2026-01-06 10:52:22 ing_pi05.py:660 State values are not normalized between -1 and 1. Min: -1.2109375, Max: 0.9296875
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# WARNING 2026-01-06 10:52:23 ing_pi05.py:660 State values are not normalized between -1 and 1. Min: -1.2109375, Max: 0.9296875
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# WARNING 2026-01-06 10:52:23 ing_pi05.py:660 State values are not normalized between -1 and 1. Min: -1.2109375, Max: 0.9296875
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# WARNING 2026-01-06 10:52:24 ing_pi05.py:660 State values are not normalized between -1 and 1. Min: -1.2109375, Max: 0.9296875
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# WARNING 2026-01-06 10:52:24 ing_pi05.py:660 State values are not normalized between -1 and 1. Min: -1.2109375, Max: 0.9296875
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# WARNING 2026-01-06 10:52:24 ing_pi05.py:660 State values are not normalized between -1 and 1. Min: -1.2109375, Max: 0.9296875
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# WARNING 2026-01-06 10:52:25 ing_pi05.py:660 State values are not normalized between -1 and 1. Min: -1.2109375, Max: 0.9296875
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# WARNING 2026-01-06 10:52:25 ing_pi05.py:660 State values are not normalized between -1 and 1. Min: -1.2109375, Max: 0.9296875
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# WARNING 2026-01-06 10:52:26 ing_pi05.py:660 State values are not normalized between -1 and 1. Min: -1.2109375, Max: 0.9296875
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# WARNING 2026-01-06 10:52:26 ing_pi05.py:660 State values are not normalized between -1 and 1. Min: -1.2109375, Max: 0.9296875
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# WARNING 2026-01-06 10:52:26 ing_pi05.py:660 State values are not normalized between -1 and 1. Min: -1.2109375, Max: 0.9296875
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# WARNING 2026-01-06 10:52:27 ing_pi05.py:660 State values are not normalized between -1 and 1. Min: -1.2109375, Max: 0.9296875
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# WARNING 2026-01-06 10:52:27 ing_pi05.py:660 State values are not normalized between -1 and 1. Min: -1.2109375, Max: 0.9296875
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# Output shape: (1, 32)
# INFO 2026-01-06 10:52:28 inference.py:65 End of inference
